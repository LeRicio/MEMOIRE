# %% [markdown]
# <a href="https://colab.research.google.com/github/LeRicio/MEMOIRE/blob/main/Configuration_environnement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Monter Google Drive**

# %%
# Importer la bibliothèque permettant de connecter Google Drive à Colab
from google.colab import drive

# Monter Google Drive dans le dossier /content/drive
drive.mount('/content/drive')

# %% [markdown]
# **Charger les images**

# %%
import os  # Permet de manipuler les chemins de fichiers

# Chemin vers ton dossier contenant les images
DATA_DIR = "/content/drive/MyDrive/CNN_DATASET"

# Vérifier que le dossier existe et afficher son contenu
print("Contenu du dossier :", os.listdir(DATA_DIR))

# %% [markdown]
# **Créer les DataLoader**

# %%
from torch.utils.data import DataLoader

# Création du DataLoader pour l'entraînement
train_loader = DataLoader(
    train_dataset,
    batch_size=32,   # Nombre d'images par batch
    shuffle=True,    # Mélanger les images à chaque époque
    num_workers=2    # Accélère le chargement
)

# DataLoader pour validation
val_loader = DataLoader(
    val_dataset,
    batch_size=32,
    shuffle=False
)

# %% [markdown]
# **Vérifier que le GPU fonctionne**

# %%
import torch  # Bibliothèque principale pour le Deep Learning

# Vérifie si un GPU est disponible
print("GPU disponible :", torch.cuda.is_available())

# Si GPU disponible, afficher son nom
if torch.cuda.is_available():
    print("Nom du GPU :", torch.cuda.get_device_name(0))
