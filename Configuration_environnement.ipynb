# %% [markdown]
# <a href="https://colab.research.google.com/github/LeRicio/MEMOIRE/blob/main/Configuration_environnement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Monter Google Drive**

# %% [markdown]
# **Charger les images**

# %% [markdown]
# **Créer les DataLoader**

# %% [markdown]
# **Vérifier que le GPU fonctionne**
